# %%
#importando as bibliotecas

import pandas as pd

#Importar os gráficos inline
# %matplotlib inline

# %%
#Importar apenas algumas colunas do arquivo

#0,2,3,4,5,7,9,10,12

df=pd.read_csv('sia112018.csv',sep=';',encoding='cp1252',usecols=[0,2,3,4,5,7,9,10,12])

df.head()
# Out:
#    ano_mes              estabelecimento_cnes       complexidade  cod_grupo  \
# 0   201811  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade          6
# 1   201811  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade          6
# 2   201811  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade          6
# 3   201811  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade          6
# 4   201811  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade          6
#
#                grupo                                           subgrupo  \
# 0  06 - Medicamentos  Sub Grupo: 04 - Componente Especializado da As...
# 1  06 - Medicamentos  Sub Grupo: 04 - Componente Especializado da As...
# 2  06 - Medicamentos  Sub Grupo: 04 - Componente Especializado da As...
# 3  06 - Medicamentos  Sub Grupo: 04 - Componente Especializado da As...
# 4  06 - Medicamentos  Sub Grupo: 04 - Componente Especializado da As...
#
#                            procedimento  quantidade carater_atendimento
# ...

# %%
#listar estabelecimentos presentes nos dados

df['estabelecimento_cnes'].unique()
# Out:
# array(['FARMACIA DE ALTO CUSTO - ASA SUL',
#        'IDR SAMAMBAIA SERVICOS MEDICOS', 'CEAL LP', 'SOCLIMED',
#        'INSTITUTO HOSPITAL DE BASE DO DISTRITO FEDERAL', 'HRAN', 'CBV',
#        'HRS', 'HOSPITAL REGIONAL DE CEILANDIA', 'HRG', 'HRL', 'NEPHRON',
#        'INSTITUTO DE CARDIOLOGIA DO DISTRITO FEDERAL',
#        'SEANE SERVICO DE ASSISTENCIA CLIN',
#        'HRT HOSPITAL REGIONAL DE TAGUATINGA',
#        'FARMACIA DE ALTO CUSTO - CEILANDIA',
#        'HOSPITAL DA CRIANCA DE BRASILIA JOSE ALENCAR-HCB',
#        'HOSPITAL UNIVERSITARIO DE BRASILIA',
#        'BANCO DE OLHOS DO DISTRITO FEDERAL', 'RENAL CARE',
#        'FARMACIA DE ALTO CUSTO GAMA', 'POLICLINICA RIACHO FUNDO I',
#        'POLICLINICA 03 DO LAGO SUL',
#        'POLICLINA DA REGIAO OESTE UNIDADE BRAZLANDIA',
#        'POLICLINICA 514 SUL - GSAS2 DIRASE/SRSCE',
#        'LABORATORIO CENTRAL DA REGIAO DE SAUDE SUDOESTE',
#        'POLICLINICA DE SOBRADINHO', 'CEDOH ASA NORTE',
# ...

# %%
df['estabelecimento_cnes'].value_counts()
# Out:
# HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB      18929
# FARMACIA DE ALTO CUSTO - CEILANDIA                15693
# INSTITUTO HOSPITAL DE BASE DO DISTRITO FEDERAL    15191
# FARMACIA DE ALTO CUSTO - ASA SUL                  13876
# HRT HOSPITAL REGIONAL DE TAGUATINGA               11156
#                                                   ...
# SAMU DF USB - SAO SEBASTIAO I                         1
# SAMU DF USB - PLANALTINA II                           1
# SAMU DF USB - CEILANDIA II                            1
# SAMU DF USB - TAGUATINGA I                            1
# SAMU DF USB - PLANO PILOTO I                          1
# Name: estabelecimento_cnes, Length: 147, dtype: int64

# %%
df['subgrupo'].value_counts()
# Out:
# Sub Grupo: 04 - Componente Especializado da Assitencia Farmaceutica                                  38398
# Sub Grupo: 01 - Consultas / Atendimentos / Acompanhamentos                                           38249
# Sub Grupo: 02 - Diagnóstico em laboratório clínico                                                   27327
# Sub Grupo: 03 - Diagnóstico por anatomia patológica e citopatologia                                  19364
# Sub Grupo: 05 - Diagnóstico por ultra-sonografia                                                      8315
# Sub Grupo: 06 - Diagnóstico por tomografia                                                            8018
# Sub Grupo: 02 - Fisioterapia                                                                          7207
# Sub Grupo: 11 - Métodos diagnósticos em especialidades                                                4732
# Sub Grupo: 04 - Tratamento em oncologia                                                               3766
# ...

# %%
#plotar o gráfico por subgrupo

df['subgrupo'].value_counts().plot.bar()

# %%
#criar um subconjunto dos dados

df_hosp = df[df['estabelecimento_cnes'] == 'HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB']

df_hosp.head()
# Out:
#        ano_mes                          estabelecimento_cnes  \
# 11280   201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
# 11294   201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
# 11308   201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
# 11429   201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
# 11471   201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
#
#              complexidade  cod_grupo  \
# 11280  Média complexidade          2
# 11294  Média complexidade          2
# 11308  Média complexidade          2
# 11429  Média complexidade          2
# 11471  Média complexidade          2
#
#                                                grupo  \
# 11280  02 - Procedimentos com Finalidade Diagnóstica
# 11294  02 - Procedimentos com Finalidade Diagnóstica
# 11308  02 - Procedimentos com Finalidade Diagnóstica
# 11429  02 - Procedimentos com Finalidade Diagnóstica
# 11471  02 - Procedimentos com Finalidade Diagnóstica
#
# ...

# %%
df_hosp['complexidade'].value_counts()
# Out:
# Média complexidade    18435
# Atenção Básica          253
# Alta complexidade       188
# Não se aplica            53
# Name: complexidade, dtype: int64

# %%
df_hosp['procedimento'].value_counts()
# Out:
# Exame Citopatológico Cervico Vaginal/microflora-rastreamento                                            12327
# Exame Citopatologico Cervico-vaginal/microflora                                                          3415
# Consulta Medica em Atenção Especializada                                                                  593
# Mamografia Bilateral para Rastreamento                                                                    480
# Exame Anatomo-patológico para Congelamento / Parafina por Peça Cirúrgica ou por Biopsia (exceto Colo      192
#                                                                                                         ...
# Dosagem de Creatinofosfoquinase (cpk)                                                                       1
# Hemograma Completo                                                                                          1
# ...

# %%
#fazer a pesquisa subdividda no dataframe por pedaços de palavras

df_hosp[df_hosp['procedimento'].str.contains('Mamografia')]
# Out:
#         ano_mes                          estabelecimento_cnes  \
# 15237    201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
# 15238    201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
# 15239    201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
# 15240    201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
# 15241    201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
# ...         ...                                           ...
# 176590   201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
# 176620   201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
# 176638   201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
# 179008   201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
# 179450   201811  HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB
#
#               complexidade  cod_grupo  \
# 15237   Média complexidade          2
# 15238   Média complexidade          2
# 15239   Média complexidade          2
# 15240   Média complexidade          2
# ...

# %%
df_hosp['carater_atendimento'].value_counts()
# Out:
# Eletivo     17667
# BPA-C        1052
# Urgência      210
# Name: carater_atendimento, dtype: int64

# %%
df_exames = df[df['procedimento'] == 'Exame']

df.head()
# Out:
#    ano_mes              estabelecimento_cnes       complexidade  cod_grupo  \
# 0   201811  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade          6
# 1   201811  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade          6
# 2   201811  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade          6
# 3   201811  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade          6
# 4   201811  FARMACIA DE ALTO CUSTO - ASA SUL  Alta complexidade          6
#
#                grupo                                           subgrupo  \
# 0  06 - Medicamentos  Sub Grupo: 04 - Componente Especializado da As...
# 1  06 - Medicamentos  Sub Grupo: 04 - Componente Especializado da As...
# 2  06 - Medicamentos  Sub Grupo: 04 - Componente Especializado da As...
# 3  06 - Medicamentos  Sub Grupo: 04 - Componente Especializado da As...
# 4  06 - Medicamentos  Sub Grupo: 04 - Componente Especializado da As...
#
#                            procedimento  quantidade carater_atendimento
# ...

# %%
df_exames['estabelecimento_cnes'].value_counts()
# Out:
# Series([], Name: estabelecimento_cnes, dtype: int64)

# %%
df_exames['carater_atendimento'].value_counts()
# Out:
# Series([], Name: carater_atendimento, dtype: int64)
