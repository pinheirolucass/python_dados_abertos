# %% [markdown]
# # Análise de Dados de eleitores brasileiros 2018

# %%
#importando bibliotecas

import pandas as pd

# %%
#carregar o arquivo csv

df = pd.read_csv('eleitorado_municipio_2018.csv',sep=';',encoding='latin1')

df.head()
# Out:
#    NR_ANO_ELEICAO  CD_PAIS NM_PAIS SG_REGIAO NM_REGIAO SG_UF NM_UF  \
# 0            2018        1  Brasil         N     Norte    AC  Acre
# 1            2018        1  Brasil         N     Norte    AC  Acre
# 2            2018        1  Brasil         N     Norte    AC  Acre
# 3            2018        1  Brasil         N     Norte    AC  Acre
# 4            2018        1  Brasil         N     Norte    AC  Acre
#
#    CD_MUNICIPIO  NM_MUNICIPIO  QTD_ELEITORES  ...  QTD_ELEITORES_90A94  \
# 0          1120    ACRELÂNDIA           8809  ...                    8
# 1          1570  ASSIS BRASIL           5726  ...                   14
# 2          1058     BRASILÉIA          16041  ...                   14
# 3          1007        BUJARI           8683  ...                   11
# 4          1015      CAPIXABA           6832  ...                    5
#
#    QTD_ELEITORES_95A99  QTD_ELEITORES_MAIORIGUAL100  \
# 0                    2                            0
# ...

# %%
#tipo e quantidade dos dados

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5741 entries, 0 to 5740
# Data columns (total 43 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   NR_ANO_ELEICAO                   5741 non-null   int64
#  1   CD_PAIS                          5741 non-null   int64
#  2   NM_PAIS                          5741 non-null   object
#  3   SG_REGIAO                        5741 non-null   object
#  4   NM_REGIAO                        5741 non-null   object
#  5   SG_UF                            5741 non-null   object
#  6   NM_UF                            5741 non-null   object
#  7   CD_MUNICIPIO                     5741 non-null   int64
#  8   NM_MUNICIPIO                     5741 non-null   object
#  9   QTD_ELEITORES                    5741 non-null   int64
#  10  QTD_ELEITORES_FEMININO           5741 non-null   int64
#  11  QTD_ELEITORES_MASCULINO          5741 non-null   int64
# ...

# %%
#quantidade de eleitores por UF

df.groupby('SG_UF')['QTD_ELEITORES'].sum()
# Out:
# SG_UF
# AC      547680
# AL     2187967
# AM     2428098
# AP      512110
# BA    10393170
# CE     6344483
# DF     2084356
# ES     2754728
# GO     4454497
# MA     4537237
# MG    15700966
# MS     1877982
# MT     2330281
# PA     5499283
# PB     2867649
# PE     6570072
# PI     2370894
# PR     7971087
# RJ    12408340
# RN     2373619
# RO     1175733
# RR      333464
# RS     8354732
# SC     5070212
# SE     1577058
# SP    33040411
# TO     1039439
# ZZ      500727
# Name: QTD_ELEITORES, dtype: int64

# %%
#Cidades com maior número de eleitores deficientes

df.nlargest(5,'QTD_ELEITORES_DEFICIENTE')
# Out:
#       NR_ANO_ELEICAO  CD_PAIS NM_PAIS SG_REGIAO NM_REGIAO SG_UF  \
# 5358            2018        1  Brasil        SE   Sudeste    SP
# 3660            2018        1  Brasil        SE   Sudeste    RJ
# 4990            2018        1  Brasil        SE   Sudeste    SP
# 535             2018        1  Brasil        NE  Nordeste    BA
# 4010            2018        1  Brasil         S       Sul    RS
#
#                   NM_UF  CD_MUNICIPIO    NM_MUNICIPIO  QTD_ELEITORES  ...  \
# 5358          São Paulo         71072       SÃO PAULO        9052724  ...
# 3660     Rio de Janeiro         60011  RIO DE JANEIRO        4891885  ...
# 4990          São Paulo         64777       GUARULHOS         814342  ...
# 535               Bahia         38490        SALVADOR        1827436  ...
# 4010  Rio Grande do Sul         85995   CAXIAS DO SUL         322901  ...
#
#       QTD_ELEITORES_90A94  QTD_ELEITORES_95A99  QTD_ELEITORES_MAIORIGUAL100  \
# ...

# %%
print('Eleitoras',df['QTD_ELEITORES_FEMININO'].sum())

print('Eleitores',df['QTD_ELEITORES_MASCULINO'].sum())

print('Não Informado',df['QTD_ELEITORES_NAOINFORMADO'].sum())
# Out:
# Eleitoras 77339897
# Eleitores 69902977
# Não Informado 63401

# %%
#Criar variáveis para calcular percentual

tot_eleitores = df['QTD_ELEITORES'].sum()
tot_feminino = df['QTD_ELEITORES_FEMININO'].sum()
tot_masculino = df['QTD_ELEITORES_MASCULINO'].sum()
tot_nao = df['QTD_ELEITORES_NAOINFORMADO'].sum()

# %%
#mostrando o resultado de eleitores em porcentagem

print('Eleitoras',((tot_feminino/tot_eleitores)*100).round(2))

print('Eleitores',((tot_masculino/tot_eleitores)*100).round(2))

print('Não Informado', ((tot_nao/tot_eleitores)*100).round(2))
# Out:
# Eleitoras 52.5
# Eleitores 47.45
# Não Informado 0.04

# %%
#quantas cidades possuem mais mulheres eleitoras do que homens

df[df['QTD_ELEITORES_FEMININO'] > df['QTD_ELEITORES_MASCULINO']].count()
# Out:
# NR_ANO_ELEICAO                     3446
# CD_PAIS                            3446
# NM_PAIS                            3446
# SG_REGIAO                          3446
# NM_REGIAO                          3446
# SG_UF                              3446
# NM_UF                              3446
# CD_MUNICIPIO                       3446
# NM_MUNICIPIO                       3446
# QTD_ELEITORES                      3446
# QTD_ELEITORES_FEMININO             3446
# QTD_ELEITORES_MASCULINO            3446
# QTD_ELEITORES_NAOINFORMADO         3446
# QTD_ELEITORES_MENOR16              3446
# QTD_ELEITORES_16                   3446
# QTD_ELEITORES_17                   3446
# QTD_ELEITORES_18                   3446
# QTD_ELEITORES_19                   3446
# QTD_ELEITORES_20                   3446
# QTD_ELEITORES_21A24                3446
# QTD_ELEITORES_25A29                3446
# QTD_ELEITORES_30A34                3446
# QTD_ELEITORES_35A39                3446
# ...

# %%
#Criar uma coluna nova para indicar a relação fem/masc

df['RELACAO_FEM_MASC'] = df['QTD_ELEITORES_FEMININO'] / df['QTD_ELEITORES_MASCULINO']

# %%
#Municipios com a amaior relação fem/masc

df.nlargest(5,'RELACAO_FEM_MASC')
# Out:
#       NR_ANO_ELEICAO  CD_PAIS   NM_PAIS SG_REGIAO NM_REGIAO SG_UF     NM_UF  \
# 5581            2018        2  Exterior         E  Exterior    ZZ  Exterior
# 5613            2018        2  Exterior         E  Exterior    ZZ  Exterior
# 5652            2018        2  Exterior         E  Exterior    ZZ  Exterior
# 5658            2018        2  Exterior         E  Exterior    ZZ  Exterior
# 5653            2018        2  Exterior         E  Exterior    ZZ  Exterior
#
#       CD_MUNICIPIO NM_MUNICIPIO  QTD_ELEITORES  ...  QTD_ELEITORES_95A99  \
# 5581         99350       BAMAKO              1  ...                    0
# 5613         38920      COTONOU              2  ...                    0
# 5652         99422       LETHEM              1  ...                    0
# 5658         29963         LOMÉ              3  ...                    0
# 5653         29939   LIBREVILLE             21  ...                    0
#
#       QTD_ELEITORES_MAIORIGUAL100  QTD_ELEITORES_IDADEINVALIDO  \
# ...

# %%
#municipios com a menor relação fem/masc

df.nsmallest(5,'RELACAO_FEM_MASC')
# Out:
#       NR_ANO_ELEICAO  CD_PAIS   NM_PAIS SG_REGIAO NM_REGIAO SG_UF     NM_UF  \
# 5592            2018        2  Exterior         E  Exterior    ZZ  Exterior
# 5610            2018        2  Exterior         E  Exterior    ZZ  Exterior
# 5625            2018        2  Exterior         E  Exterior    ZZ  Exterior
# 5719            2018        2  Exterior         E  Exterior    ZZ  Exterior
# 5639            2018        2  Exterior         E  Exterior    ZZ  Exterior
#
#       CD_MUNICIPIO  NM_MUNICIPIO  QTD_ELEITORES  ...  QTD_ELEITORES_95A99  \
# 5592         39187   BRAZZAVILLE              3  ...                    0
# 5610         38903       CONACRI              2  ...                    0
# 5625         99406      FREETOWN              2  ...                    0
# 5719         30546         SÓFIA             16  ...                    0
# 5639         38989  IEREVAN-ARME             12  ...                    0
#
# ...

# %%
#quantidade de eleitores sem biometria por UF

df.groupby('SG_UF')['QTD_ELEITORES_SEMBIOMETRIA'].sum()
# Out:
# SG_UF
# AC       73894
# AL        7041
# AM      387100
# AP        1417
# BA     3558894
# CE     1407526
# DF        5903
# ES     1505317
# GO        6762
# MA     1156404
# MG    10964390
# MS      861011
# MT     1189919
# PA     2006749
# PB        5330
# PE     1865577
# PI        1647
# PR      807022
# RJ    10089206
# RN        7867
# RO      208337
# RR         464
# RS     3363519
# SC     1853848
# SE        2484
# SP    18124772
# TO         632
# ZZ      480145
# Name: QTD_ELEITORES_SEMBIOMETRIA, dtype: int64

# %%
#criar um dataframe somente com municípios brasileiros

df_brasil = df[df['CD_PAIS'] == 1].copy()

df_brasil.head()
# Out:
#    NR_ANO_ELEICAO  CD_PAIS NM_PAIS SG_REGIAO NM_REGIAO SG_UF NM_UF  \
# 0            2018        1  Brasil         N     Norte    AC  Acre
# 1            2018        1  Brasil         N     Norte    AC  Acre
# 2            2018        1  Brasil         N     Norte    AC  Acre
# 3            2018        1  Brasil         N     Norte    AC  Acre
# 4            2018        1  Brasil         N     Norte    AC  Acre
#
#    CD_MUNICIPIO  NM_MUNICIPIO  QTD_ELEITORES  ...  QTD_ELEITORES_95A99  \
# 0          1120    ACRELÂNDIA           8809  ...                    2
# 1          1570  ASSIS BRASIL           5726  ...                    4
# 2          1058     BRASILÉIA          16041  ...                    4
# 3          1007        BUJARI           8683  ...                    2
# 4          1015      CAPIXABA           6832  ...                    1
#
#    QTD_ELEITORES_MAIORIGUAL100  QTD_ELEITORES_IDADEINVALIDO  \
# 0                            0                            0
# ...

# %%
#quantas cidades possuem mais mulheres eleitoras do que homens

df_brasil[df_brasil['QTD_ELEITORES_FEMININO'] > df_brasil['QTD_ELEITORES_MASCULINO']].count()
# Out:
# NR_ANO_ELEICAO                     3321
# CD_PAIS                            3321
# NM_PAIS                            3321
# SG_REGIAO                          3321
# NM_REGIAO                          3321
# SG_UF                              3321
# NM_UF                              3321
# CD_MUNICIPIO                       3321
# NM_MUNICIPIO                       3321
# QTD_ELEITORES                      3321
# QTD_ELEITORES_FEMININO             3321
# QTD_ELEITORES_MASCULINO            3321
# QTD_ELEITORES_NAOINFORMADO         3321
# QTD_ELEITORES_MENOR16              3321
# QTD_ELEITORES_16                   3321
# QTD_ELEITORES_17                   3321
# QTD_ELEITORES_18                   3321
# QTD_ELEITORES_19                   3321
# QTD_ELEITORES_20                   3321
# QTD_ELEITORES_21A24                3321
# QTD_ELEITORES_25A29                3321
# QTD_ELEITORES_30A34                3321
# QTD_ELEITORES_35A39                3321
# ...

# %%
#Municipios brasileiros com a amaior relação fem/masc

df_brasil.nlargest(5,'RELACAO_FEM_MASC')
# Out:
#       NR_ANO_ELEICAO  CD_PAIS NM_PAIS SG_REGIAO NM_REGIAO SG_UF  \
# 3653            2018        1  Brasil        SE   Sudeste    RJ
# 535             2018        1  Brasil        NE  Nordeste    BA
# 2894            2018        1  Brasil        NE  Nordeste    PE
# 373             2018        1  Brasil        NE  Nordeste    BA
# 329             2018        1  Brasil        NE  Nordeste    BA
#
#                NM_UF  CD_MUNICIPIO      NM_MUNICIPIO  QTD_ELEITORES  ...  \
# 3653  Rio de Janeiro         58122         QUEIMADOS          72971  ...
# 535            Bahia         38490          SALVADOR        1827436  ...
# 2894      Pernambuco         24910            OLINDA         276081  ...
# 373            Bahia         35939             IRECÊ          44082  ...
# 329            Bahia         35157  FEIRA DE SANTANA         384050  ...
#
#       QTD_ELEITORES_95A99  QTD_ELEITORES_MAIORIGUAL100  \
# 3653                    6                            3
# ...

# %%
#Municipios brasileiros com a menor relação fem/masc

df_brasil.nsmallest(5,'RELACAO_FEM_MASC')
# Out:
#       NR_ANO_ELEICAO  CD_PAIS NM_PAIS SG_REGIAO     NM_REGIAO SG_UF  \
# 2389            2018        1  Brasil        CO  Centro-Oeste    MT
# 1237            2018        1  Brasil        NE      Nordeste    MA
# 2362            2018        1  Brasil        CO  Centro-Oeste    MT
# 2396            2018        1  Brasil        CO  Centro-Oeste    MT
# 2361            2018        1  Brasil        CO  Centro-Oeste    MT
#
#             NM_UF  CD_MUNICIPIO         NM_MUNICIPIO  QTD_ELEITORES  ...  \
# 2389  Mato Grosso         90980  SANTA CRUZ DO XINGU           1571  ...
# 1237     Maranhão          7900       MARAJÁ DO SENA           6416  ...
# 2362  Mato Grosso         90948   NOVO SANTO ANTÔNIO           1701  ...
# 2396  Mato Grosso         90921   SERRA NOVA DOURADA           1379  ...
# 2361  Mato Grosso         90808           NOVO MUNDO           5064  ...
#
#       QTD_ELEITORES_95A99  QTD_ELEITORES_MAIORIGUAL100  \
# 2389                    0                            0
# ...

# %%
#municipios com maior número de pessoas com 16 anos

df_brasil.nlargest(5,'QTD_ELEITORES_16')
# Out:
#       NR_ANO_ELEICAO  CD_PAIS NM_PAIS SG_REGIAO     NM_REGIAO SG_UF  \
# 5358            2018        1  Brasil        SE       Sudeste    SP
# 677             2018        1  Brasil        NE      Nordeste    CE
# 803             2018        1  Brasil        CO  Centro-Oeste    DF
# 161             2018        1  Brasil         N         Norte    AM
# 3660            2018        1  Brasil        SE       Sudeste    RJ
#
#                  NM_UF  CD_MUNICIPIO    NM_MUNICIPIO  QTD_ELEITORES  ...  \
# 5358         São Paulo         71072       SÃO PAULO        9052724  ...
# 677              Ceará         13897       FORTALEZA        1776365  ...
# 803   Distrito Federal         97012        BRASÍLIA        2084356  ...
# 161           Amazonas          2550          MANAUS        1320059  ...
# 3660    Rio de Janeiro         60011  RIO DE JANEIRO        4891885  ...
#
#       QTD_ELEITORES_95A99  QTD_ELEITORES_MAIORIGUAL100  \
# 5358                33110                         3439
# ...

# %%
#Municipios com a maior quantidade de pessoas que optaram por nome social

df_brasil.nlargest(5,'QUANTITATIVO_NOMESOCIAL')
# Out:
#       NR_ANO_ELEICAO  CD_PAIS NM_PAIS SG_REGIAO NM_REGIAO SG_UF  \
# 5358            2018        1  Brasil        SE   Sudeste    SP
# 3660            2018        1  Brasil        SE   Sudeste    RJ
# 677             2018        1  Brasil        NE  Nordeste    CE
# 535             2018        1  Brasil        NE  Nordeste    BA
# 1406            2018        1  Brasil        SE   Sudeste    MG
#
#                NM_UF  CD_MUNICIPIO    NM_MUNICIPIO  QTD_ELEITORES  ...  \
# 5358       São Paulo         71072       SÃO PAULO        9052724  ...
# 3660  Rio de Janeiro         60011  RIO DE JANEIRO        4891885  ...
# 677            Ceará         13897       FORTALEZA        1776365  ...
# 535            Bahia         38490        SALVADOR        1827436  ...
# 1406    Minas Gerais         41238  BELO HORIZONTE        1956410  ...
#
#       QTD_ELEITORES_95A99  QTD_ELEITORES_MAIORIGUAL100  \
# 5358                33110                         3439
# ...

# %%
# Histograma de distribuição da relação de fem / masc
#abaixo de 1 é a quantidade de municipios com mais homens eleitores que mulheres, acima de 1 é a quantidade de municipios com mais eleitores mulheres

df_brasil['RELACAO_FEM_MASC'].plot.hist(bins=100)

# %%
#importar nova biblioteca de gráficos

import seaborn as sns
import matplotlib.pyplot as plt

# %%
#plotar a distribuição da relação fem/masc

sns.distplot(df_brasil['RELACAO_FEM_MASC'],bins=100,color ='red',kde = False)

#incrementando gráfico

plt.title('Relação de Eleitoras/Eleitores',fontsize=18)

plt.xlabel('Eleitoras/Eleitores',fontsize=14)
plt.ylabel('Frequência',fontsize=14)
plt.axvline(1.0, color='black', linestyle='--')

# %%
#verificar a distribuição fem/ masc mostrando os pontos (municipior)

sns.swarmplot(data=df_brasil, x='NM_REGIAO',y='RELACAO_FEM_MASC')
plt.axhline(1, color='black',linestyle='--')

# %%
#relatório com somatório de faixas etárias por quantidade de eleitores

#selecionar colunas que iremos usar

lista = ['QTD_ELEITORES_16','QTD_ELEITORES_17','QTD_ELEITORES_18','QTD_ELEITORES_19','QTD_ELEITORES_20','QTD_ELEITORES_21A24','QTD_ELEITORES_25A29',
        'QTD_ELEITORES_30A34','QTD_ELEITORES_35A39','QTD_ELEITORES_40A44','QTD_ELEITORES_45A49','QTD_ELEITORES_50A54','QTD_ELEITORES_55A59',
        'QTD_ELEITORES_60A64','QTD_ELEITORES_65A69','QTD_ELEITORES_70A74','QTD_ELEITORES_75A79','QTD_ELEITORES_80A84',
        'QTD_ELEITORES_85A89','QTD_ELEITORES_90A94','QTD_ELEITORES_95A99','QTD_ELEITORES_MAIORIGUAL100']

idades = df_brasil[lista].sum()

# %%
idades
# Out:
# QTD_ELEITORES_16                 403630
# QTD_ELEITORES_17                 996606
# QTD_ELEITORES_18                2324698
# QTD_ELEITORES_19                2814032
# QTD_ELEITORES_20                3030108
# QTD_ELEITORES_21A24            12622963
# QTD_ELEITORES_25A29            15218736
# QTD_ELEITORES_30A34            15830929
# QTD_ELEITORES_35A39            16128455
# QTD_ELEITORES_40A44            14152227
# QTD_ELEITORES_45A49            12767356
# QTD_ELEITORES_50A54            12168810
# QTD_ELEITORES_55A59            10649977
# QTD_ELEITORES_60A64             8881005
# QTD_ELEITORES_65A69             6796233
# QTD_ELEITORES_70A74             4756393
# QTD_ELEITORES_75A79             3167513
# QTD_ELEITORES_80A84             1971647
# QTD_ELEITORES_85A89             1121195
# QTD_ELEITORES_90A94              688768
# QTD_ELEITORES_95A99              272334
# QTD_ELEITORES_MAIORIGUAL100       39026
# dtype: int64

# %%
#mostrar no gráfico

idades.plot.barh()
